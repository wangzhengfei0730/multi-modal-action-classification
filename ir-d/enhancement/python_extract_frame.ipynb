# %%
import cv2

# %%
cap = cv2.VideoCapture('0002-L-infrared.avi')

# %%
ret, frame = cap.read()

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(frame)

# %%
cv2.imwrite('origin.jpg', frame)
# Out:
# True

# %%
import numpy as np

# %%
python_processed = np.uint8(np.clip((10 * frame + 50), 0, 255))

# %%
plt.imshow(python_processed)
